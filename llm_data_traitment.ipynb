# %% [markdown]
# ## Filtrage par gemini 1.5 Flash

# %%
import os
import pandas as pd
from dotenv import load_dotenv
import google.generativeai as genai
import ast
import time

iteration = 6

# Chargement des variables d'environnement
load_dotenv()

# Configuration de l'API Gemini
genai.configure(api_key=os.getenv("API_KEY"))

# Définition du system_prompt et du prompt utilisateur
system_prompt = '''
You are an expert Smartphone analyzer. Your task is to analyze an image of a smartphone on a white background and answer specific questions about it. Here is the image you need to analyze:
Please carefully examine the image, then answer the following questions.
'''

# Liste des questions (facilement modifiable pour les futurs prompts)
questions = [
    'Is there one smartphone on a white background? (Answer only by "Yes" or "No")',
    'Which face of the Smartphone is shown: the front (screen side) or back (camera side) or other side of the device? (Answer only by "Front" or "Back" or "Other")',
]

# Construction du prompt utilisateur à partir de la liste des questions
prompt = '\n'.join(questions)

# Nom du modèle et configuration de génération
model_name = "gemini-1.5-flash"
generation_config = {
    "temperature": 0.2,
    "top_p": 0.9,
    "top_k": 40,
    "max_output_tokens": 200,
    "response_mime_type": "text/plain",
}

# %%
# Fonction pour analyser une image avec l'IA
def analyze_image(image_path, system_prompt, prompt, model_name, generation_config):
    """Analyse une image en utilisant le modèle Gemini et retourne les réponses."""
    try:
        time.sleep(0.01)
        # Télécharger l'image vers Gemini
        file = genai.upload_file(image_path)
        # Créer une session de chat avec le modèle
        model = genai.GenerativeModel(
            model_name=model_name,
            generation_config=generation_config,
            system_instruction=system_prompt,
        )
        chat_session = model.start_chat(history=[])
        # Préparer le message avec l'image et le prompt
        message = [file, prompt]
        # Envoyer le message et obtenir la réponse
        response = chat_session.send_message(message)
        
        print(f'Image: {image_path} correctly analyzed')
        return response.text.strip()
    except Exception as e:
        print(f"Erreur lors de l'analyse de l'image {image_path}: {e}")
        return None

# %%
# Chargement du DataFrame principal
df_ai = pd.read_csv(f'Data/{iteration}/smartphone_infos_{iteration}.csv')

# Conversion de la colonne 'Images_Path' de chaîne en liste si nécessaire
df_ai['Images_Path'] = df_ai['Images_Path'].apply(ast.literal_eval)

# Nombre de questions
num_questions = len(questions)

# Initialisation des colonnes pour stocker les réponses
for i in range(1, num_questions + 1):
    df_ai[f'Answer_{i}'] = [[] for _ in range(len(df_ai))]

# %%
df_ai
# Out:
#       Unnamed: 0                         title  \
# 0              1                     IPhone 11
# 1              4                    IPhone 7 💫
# 2              9             Iphone 15 pro Max
# 3             10                  IPhone apple
# 4             11                        Réveil
# ...          ...                           ...
# 1714        2984  Iphone 13 à vendre sur Paris
# 1715        2985         IPhone 13 128GO blanc
# 1716        2993         Iphone 13 128Go Blanc
# 1717        2995                     Iphone 11
# 1718        2999                     Iphone 6s
#
#                                                    link    price  \
# 0     https://www.leboncoin.fr/ad/telephones_objets_...    255 €
# 1     https://www.leboncoin.fr/ad/telephones_objets_...     50 €
# 2     https://www.leboncoin.fr/ad/telephones_objets_...  1 000 €
# 3     https://www.leboncoin.fr/ad/telephones_objets_...     70 €
# 4     https://www.leboncoin.fr/ad/telephones_objets_...     10 €
# ...                                                 ...      ...
# 1714  https://www.leboncoin.fr/ad/telephones_objets_...    350 €
# 1715  https://www.leboncoin.fr/ad/telephones_objets_...    450 €
# 1716  https://www.leboncoin.fr/ad/telephones_objets_...    390 €
# 1717  https://www.leboncoin.fr/ad/telephones_objets_...    300 €
# 1718  https://www.leboncoin.fr/ad/telephones_objets_...     55 €
#
#                                             description     publication_date  \
# 0     iPhone 11 jaune 64go en très bonne état 100% d...  2024-11-16 21:21:00
# 1     Je vends un IPHONE\nJ’ai la GARANTIE, et la FA...  2024-10-08 01:06:00
# 2     Vends iPhone 15 Pro Max couleur titane, très b...  2024-11-16 21:21:00
# 3     iPhone en excellent état,vendu avec garanti et...  2024-11-23 16:42:00
# 4                        Vends réveil en très bon état.  2024-11-16 21:22:00
# ...                                                 ...                  ...
# 1714  Vendu avec facture, accessoires d’origine et g...  2024-11-25 18:39:00
# 1715  Vend iPhone  13 128GO  , en excellent état \nT...  2024-11-25 18:39:00
# 1716  Je vends mon iPhone 13 128Go car j'ai acheté u...  2024-11-25 18:41:00
# 1717  Bonjour, je vend mon iphone 11 pour m’acheter ...  2024-11-25 18:43:00
# 1718  Vend IPHONE 6S\nTrès bien pour jeune, pour un ...  2024-11-25 18:43:00
#
#       Condition  Brand              Model            Color  Memory  \
# 0             3  Apple          iPhone 11            Jaune   64 Go
# 1             3  Apple           iPhone 7             Noir   32 Go
# 2             3  Apple  iPhone 15 Pro Max  Argent / Silver  256 Go
# 3             3  Apple          iPhone SE            Rouge   64 Go
# 4             3    NaN                NaN             Noir    8 Go
# ...         ...    ...                ...              ...     ...
# 1714          4  Apple          iPhone 13           Violet  128 Go
# 1715          4  Apple          iPhone 13            Blanc  128 Go
# 1716          3  Apple          iPhone 13            Blanc  128 Go
# 1717          3  Apple          iPhone 11             Noir   64 Go
# 1718          3  Apple          iPhone 6s          Or rose     NaN
#
#                                                  images  \
# 0     ['https://img.leboncoin.fr/api/v1/lbcpb1/image...
# 1     ['https://img.leboncoin.fr/api/v1/lbcpb1/image...
# 2     ['https://img.leboncoin.fr/api/v1/lbcpb1/image...
# 3     ['https://img.leboncoin.fr/api/v1/lbcpb1/image...
# 4     ['https://img.leboncoin.fr/api/v1/lbcpb1/image...
# ...                                                 ...
# 1714  ['https://img.leboncoin.fr/api/v1/lbcpb1/image...
# 1715  ['https://img.leboncoin.fr/api/v1/lbcpb1/image...
# 1716  ['https://img.leboncoin.fr/api/v1/lbcpb1/image...
# 1717  ['https://img.leboncoin.fr/api/v1/lbcpb1/image...
# 1718  ['https://img.leboncoin.fr/api/v1/lbcpb1/image...
#
#      Spare_Parts_Availability Refurbished_Item_Condition Reparability_Index  \
# 0                         NaN                        NaN                NaN
# 1              Non renseignée                        NaN                NaN
# 2                         NaN                        NaN                NaN
# 3                         NaN                        NaN                NaN
# 4                         NaN                        NaN                NaN
# ...                       ...                        ...                ...
# 1714           Non disponible              Très bon état                NaN
# 1715                      NaN                        NaN                NaN
# 1716                      NaN                        NaN                NaN
# 1717                      NaN                        NaN                NaN
# 1718                      NaN                        NaN                NaN
#
#                                             Images_Path Answer_1 Answer_2
# 0                               [produit_0_image_0.jpg]       []       []
# 1                               [produit_1_image_0.jpg]       []       []
# 2                               [produit_2_image_0.jpg]       []       []
# 3        [produit_3_image_0.jpg, produit_3_image_1.jpg]       []       []
# 4     [produit_4_image_0.jpg, produit_4_image_1.jpg,...       []       []
# ...                                                 ...      ...      ...
# 1714  [produit_1714_image_0.jpg, produit_1714_image_...       []       []
# 1715  [produit_1715_image_0.jpg, produit_1715_image_...       []       []
# 1716  [produit_1716_image_0.jpg, produit_1716_image_...       []       []
# 1717  [produit_1717_image_0.jpg, produit_1717_image_...       []       []
# 1718  [produit_1718_image_0.jpg, produit_1718_image_...       []       []
#
# [1719 rows x 18 columns]

# %%
# Itération sur chaque produit et ses images
for idx, row in df_ai.iterrows():
    images = row['Images_Path']
    answers_per_question = [[] for _ in range(num_questions)]
    for image_name in images:
        image_path = f"Data/{iteration}/images_without_background/{image_name}"
        # Analyse de l'image avec l'IA
        response = analyze_image(image_path, system_prompt, prompt, model_name, generation_config)
        if response:
            # Traitement de la réponse
            answers = response.strip().split('\n')
            answers = [ans.strip() for ans in answers if ans.strip()]
            # Vérification du nombre de réponses
            if len(answers) != num_questions:
                print(f"Avertissement: {num_questions} réponses attendues mais {len(answers)} reçues pour l'image {image_name}")
                continue
            for i in range(num_questions):
                answers_per_question[i].append(answers[i])
        else:
            for i in range(num_questions):
                answers_per_question[i].append(None)
    # Stockage des réponses pour ce produit
    for i in range(num_questions):
        df_ai.at[idx, f'Answer_{i + 1}'] = answers_per_question[i]
# Out:
# Image: Data/6/images_without_background/produit_0_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_2_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_3_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_3_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_4_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_4_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_4_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_4_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_5_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_5_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_6_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_6_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_6_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_7_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_7_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_7_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_7_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_7_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_7_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_7_image_6.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_7_image_7.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_7_image_8.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_7_image_9.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_8_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_8_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_8_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_8_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_8_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_9_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_9_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_10_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_10_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_10_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_10_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_11_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_11_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_12_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_12_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_12_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_13_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_13_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_13_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_13_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_13_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_13_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_13_image_6.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_14_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_14_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_14_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_14_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_15_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_15_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_16_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_16_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_16_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_16_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_16_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_16_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_17_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_17_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_18_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_18_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_18_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_18_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_19_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_19_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_19_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_19_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_19_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_19_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_20_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_20_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_20_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_20_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_20_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_20_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_21_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_21_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_21_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_21_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_22_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_22_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_22_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_23_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_23_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_24_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_24_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_24_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_24_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_25_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_25_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_26_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_26_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_26_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_27_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_27_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_27_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_27_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_28_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_28_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_28_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_29_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_29_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_30_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_30_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_30_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_31_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_32_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_32_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_32_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_33_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_33_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_33_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_33_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_33_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_33_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_34_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_34_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_34_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_34_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_34_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_35_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_35_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_35_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_35_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_36_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_36_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_37_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_37_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_37_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_37_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_37_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_37_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_37_image_6.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_37_image_7.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_38_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_38_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_39_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_40_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_40_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_40_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_41_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_41_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_41_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_41_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_41_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_41_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_41_image_6.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_41_image_7.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_41_image_8.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_41_image_9.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_41_image_10.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_42_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_42_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_42_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_43_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_43_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_43_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_43_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_43_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_43_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_43_image_6.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_44_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_44_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_44_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_45_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_45_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_45_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_46_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_46_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_46_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_47_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_47_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_48_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_48_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_49_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_49_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_50_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_50_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_50_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_51_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_51_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_52_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_52_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_52_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_53_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_54_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_54_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_54_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_54_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_55_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_55_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_55_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_56_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_56_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_56_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_56_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_56_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_57_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_58_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_58_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_58_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_59_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_60_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_61_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_61_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_62_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_62_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_62_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_63_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_63_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_64_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_64_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_64_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_65_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_66_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_66_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_67_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_68_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_68_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_69_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_69_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_69_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_69_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_69_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_69_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_70_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_70_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_70_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_70_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_70_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_70_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_71_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_71_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_71_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_71_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_73_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_74_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_74_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_74_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_74_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_75_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_76_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_76_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_77_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_78_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_78_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_78_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_79_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_79_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_79_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_80_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_80_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_80_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_80_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_81_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_82_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_82_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_83_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_84_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_84_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_84_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_85_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_85_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_85_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_85_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_86_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_87_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_87_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_87_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_87_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_87_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_87_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_87_image_6.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_87_image_7.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_87_image_8.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_87_image_9.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_87_image_10.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_88_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_88_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_89_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_89_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_89_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_90_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_91_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_91_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_92_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_93_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_93_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_94_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_95_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_95_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_95_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_95_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_95_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_95_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_96_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_96_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_97_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_98_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_98_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_98_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_98_image_3.jpg correctly analyzed
# Avertissement: 2 réponses attendues mais 3 reçues pour l'image produit_98_image_3.jpg
# Image: Data/6/images_without_background/produit_98_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_99_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_99_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_99_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_100_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_101_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_102_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_103_image_0.jpg correctly analyzed
# Avertissement: 2 réponses attendues mais 3 reçues pour l'image produit_103_image_0.jpg
# Image: Data/6/images_without_background/produit_103_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_103_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_104_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_104_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_104_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_105_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_105_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_105_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_105_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_105_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_106_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_106_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_106_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_106_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_106_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_108_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_108_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_108_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_108_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_108_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_109_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_110_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_111_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_111_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_111_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_112_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_113_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_113_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_114_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_114_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_115_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_115_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_115_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_116_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_116_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_117_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_117_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_118_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_118_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_118_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_118_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_118_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_118_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_119_image_0.jpg correctly analyzed
# Avertissement: 2 réponses attendues mais 3 reçues pour l'image produit_119_image_0.jpg
# Image: Data/6/images_without_background/produit_119_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_119_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_119_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_119_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_119_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_119_image_6.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_120_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_120_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_121_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_122_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_122_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_122_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_122_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_122_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_123_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_125_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_127_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_127_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_128_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_128_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_128_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_129_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_129_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_130_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_130_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_130_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_130_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_130_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_131_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_131_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_132_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_132_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_133_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_133_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_133_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_134_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_134_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_135_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_135_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_135_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_136_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_136_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_137_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_137_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_137_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_137_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_137_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_138_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_138_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_138_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_138_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_138_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_139_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_140_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_141_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_141_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_141_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_142_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_142_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_143_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_143_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_143_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_143_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_143_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_144_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_144_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_144_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_144_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_145_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_145_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_145_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_145_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_145_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_145_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_145_image_6.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_145_image_7.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_145_image_8.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_146_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_146_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_147_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_147_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_148_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_148_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_148_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_148_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_148_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_148_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_149_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_150_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_150_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_151_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_151_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_151_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_151_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_151_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_151_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_152_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_152_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_152_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_152_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_152_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_153_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_153_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_153_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_153_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_153_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_154_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_154_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_155_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_155_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_155_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_155_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_155_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_156_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_156_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_156_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_157_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_157_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_157_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_158_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_159_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_159_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_159_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_160_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_160_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_160_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_161_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_161_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_161_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_161_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_161_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_162_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_162_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_162_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_162_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_163_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_163_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_164_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_164_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_164_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_164_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_164_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_164_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_164_image_6.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_164_image_7.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_164_image_8.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_164_image_9.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_164_image_10.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_165_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_165_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_165_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_166_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_166_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_166_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_166_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_167_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_167_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_167_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_167_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_169_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_169_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_169_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_170_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_170_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_171_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_172_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_172_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_173_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_173_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_173_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_173_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_174_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_175_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_175_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_175_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_175_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_175_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_175_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_175_image_6.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_175_image_7.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_176_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_177_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_177_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_177_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_177_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_177_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_177_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_178_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_178_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_178_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_178_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_178_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_178_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_179_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_179_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_179_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_180_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_180_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_180_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_180_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_180_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_180_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_181_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_181_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_181_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_181_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_182_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_182_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_183_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_183_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_184_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_184_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_184_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_184_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_184_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_184_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_184_image_6.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_185_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_185_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_185_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_186_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_186_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_186_image_2.jpg correctly analyzed
# ...
# Image: Data/6/images_without_background/produit_1670_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1670_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1670_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1670_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1671_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1671_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1672_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1672_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1672_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1672_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1673_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1673_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1674_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1675_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1675_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1675_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1675_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1676_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1677_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1678_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1678_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1678_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1678_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1678_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1679_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1679_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1679_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1679_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1679_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1679_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1680_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1680_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1680_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1680_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1681_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1681_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1681_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1682_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1682_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1682_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1682_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1682_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1682_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1683_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1683_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1683_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1683_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1683_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1683_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1684_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1685_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1685_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1685_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1686_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1686_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1686_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1687_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1687_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1687_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1688_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1688_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1688_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1688_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1689_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1689_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1689_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1689_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1689_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1690_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1690_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1690_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1690_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1691_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1691_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1691_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1691_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1691_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1691_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1692_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1692_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1692_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1692_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1692_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1692_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1693_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1693_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1693_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1693_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1694_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1694_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1695_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1695_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1695_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1696_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1696_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1696_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1696_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1696_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1696_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1697_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1697_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1697_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1697_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1698_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1698_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1698_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1698_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1698_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1698_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1698_image_6.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1699_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1699_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1699_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1699_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1700_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1700_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1700_image_2.jpg correctly analyzed
# Avertissement: 2 réponses attendues mais 3 reçues pour l'image produit_1700_image_2.jpg
# Image: Data/6/images_without_background/produit_1700_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1700_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1700_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1700_image_6.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1701_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1701_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1701_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1701_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1701_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1701_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1701_image_6.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1702_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1702_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1702_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1703_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1704_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1704_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1705_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1705_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1705_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1706_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1706_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1706_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1706_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1706_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1706_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1706_image_6.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1706_image_7.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1706_image_8.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1706_image_9.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1707_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1707_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1707_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1708_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1708_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1708_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1708_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1708_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1709_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1709_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1709_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1709_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1709_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1710_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1710_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1711_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1712_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1713_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1714_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1714_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1715_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1715_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1715_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1715_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1715_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1715_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1716_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1716_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1716_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1716_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1716_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1716_image_5.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1716_image_6.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1717_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1717_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1717_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1717_image_3.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1717_image_4.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1718_image_0.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1718_image_1.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1718_image_2.jpg correctly analyzed
# Image: Data/6/images_without_background/produit_1718_image_3.jpg correctly analyzed

# %%
# Filtrage des images en fonction des réponses
df_selected = pd.DataFrame(columns=['Image_Path', 'Condition', *[f'Answer_{i + 1}' for i in range(num_questions)]])

for idx, row in df_ai.iterrows():
    condition = row['Condition']
    images = row['Images_Path']
    answers_list = [row[f'Answer_{i + 1}'] for i in range(num_questions)]
    for image_path, *answers in zip(images, *answers_list):
        # Critères de filtrage (modifiable pour futurs prompts)
        if answers[0] == 'Yes':
            new_row = {
                'Image_Path': image_path,
                'Condition': condition,
                **{f'Answer_{i + 1}': answers[i] for i in range(num_questions)}
            }
            df_selected = pd.concat([df_selected, pd.DataFrame([new_row])], ignore_index=True)
        else:
            print(f"Image {image_path} ne répond pas aux critères")

# Séparation des images en fonction de la face du smartphone
df_front = df_selected[df_selected['Answer_2'] == 'Front'][['Image_Path', 'Condition']]
df_back = df_selected[df_selected['Answer_2'] == 'Back'][['Image_Path', 'Condition']]

# Sauvegarder les DataFrames traités
df_front.to_csv(f'Data/{iteration}/df_front_{iteration}.csv', index=False)
df_back.to_csv(f'Data/{iteration}/df_back_{iteration}.csv', index=False)

df_front
# Out:
# Image produit_1_image_0.jpg ne répond pas aux critères
# Image produit_4_image_0.jpg ne répond pas aux critères
# Image produit_4_image_1.jpg ne répond pas aux critères
# Image produit_4_image_2.jpg ne répond pas aux critères
# Image produit_4_image_3.jpg ne répond pas aux critères
# Image produit_8_image_4.jpg ne répond pas aux critères
# Image produit_13_image_0.jpg ne répond pas aux critères
# Image produit_13_image_3.jpg ne répond pas aux critères
# Image produit_13_image_4.jpg ne répond pas aux critères
# Image produit_20_image_3.jpg ne répond pas aux critères
# Image produit_21_image_2.jpg ne répond pas aux critères
# Image produit_27_image_3.jpg ne répond pas aux critères
# Image produit_33_image_3.jpg ne répond pas aux critères
# Image produit_37_image_0.jpg ne répond pas aux critères
# Image produit_37_image_1.jpg ne répond pas aux critères
# Image produit_37_image_2.jpg ne répond pas aux critères
# Image produit_37_image_3.jpg ne répond pas aux critères
# Image produit_37_image_4.jpg ne répond pas aux critères
# Image produit_37_image_5.jpg ne répond pas aux critères
# Image produit_37_image_6.jpg ne répond pas aux critères
# Image produit_37_image_7.jpg ne répond pas aux critères
# Image produit_46_image_1.jpg ne répond pas aux critères
# Image produit_46_image_2.jpg ne répond pas aux critères
# Image produit_62_image_0.jpg ne répond pas aux critères
# Image produit_69_image_0.jpg ne répond pas aux critères
# Image produit_69_image_1.jpg ne répond pas aux critères
# Image produit_69_image_2.jpg ne répond pas aux critères
# Image produit_69_image_3.jpg ne répond pas aux critères
# Image produit_69_image_4.jpg ne répond pas aux critères
# Image produit_69_image_5.jpg ne répond pas aux critères
# Image produit_71_image_3.jpg ne répond pas aux critères
# Image produit_76_image_0.jpg ne répond pas aux critères
# Image produit_76_image_1.jpg ne répond pas aux critères
# Image produit_82_image_1.jpg ne répond pas aux critères
# Image produit_87_image_10.jpg ne répond pas aux critères
# Image produit_88_image_1.jpg ne répond pas aux critères
# Image produit_96_image_0.jpg ne répond pas aux critères
# Image produit_96_image_1.jpg ne répond pas aux critères
# Image produit_106_image_4.jpg ne répond pas aux critères
# Image produit_135_image_0.jpg ne répond pas aux critères
# Image produit_135_image_1.jpg ne répond pas aux critères
# Image produit_135_image_2.jpg ne répond pas aux critères
# Image produit_138_image_0.jpg ne répond pas aux critères
# Image produit_138_image_1.jpg ne répond pas aux critères
# Image produit_138_image_2.jpg ne répond pas aux critères
# Image produit_138_image_3.jpg ne répond pas aux critères
# Image produit_138_image_4.jpg ne répond pas aux critères
# Image produit_145_image_4.jpg ne répond pas aux critères
# Image produit_145_image_6.jpg ne répond pas aux critères
# Image produit_145_image_7.jpg ne répond pas aux critères
# Image produit_148_image_4.jpg ne répond pas aux critères
# Image produit_149_image_0.jpg ne répond pas aux critères
# Image produit_151_image_5.jpg ne répond pas aux critères
# Image produit_158_image_0.jpg ne répond pas aux critères
# Image produit_161_image_3.jpg ne répond pas aux critères
# Image produit_165_image_0.jpg ne répond pas aux critères
# Image produit_166_image_1.jpg ne répond pas aux critères
# Image produit_166_image_2.jpg ne répond pas aux critères
# Image produit_167_image_3.jpg ne répond pas aux critères
# Image produit_176_image_0.jpg ne répond pas aux critères
# Image produit_183_image_0.jpg ne répond pas aux critères
# Image produit_183_image_1.jpg ne répond pas aux critères
# Image produit_190_image_0.jpg ne répond pas aux critères
# Image produit_194_image_11.jpg ne répond pas aux critères
# Image produit_210_image_3.jpg ne répond pas aux critères
# Image produit_213_image_0.jpg ne répond pas aux critères
# Image produit_215_image_0.jpg ne répond pas aux critères
# Image produit_215_image_1.jpg ne répond pas aux critères
# Image produit_221_image_0.jpg ne répond pas aux critères
# Image produit_221_image_2.jpg ne répond pas aux critères
# Image produit_221_image_3.jpg ne répond pas aux critères
# Image produit_221_image_4.jpg ne répond pas aux critères
# Image produit_225_image_1.jpg ne répond pas aux critères
# Image produit_227_image_0.jpg ne répond pas aux critères
# Image produit_227_image_1.jpg ne répond pas aux critères
# Image produit_229_image_2.jpg ne répond pas aux critères
# Image produit_232_image_5.jpg ne répond pas aux critères
# Image produit_232_image_7.jpg ne répond pas aux critères
# Image produit_238_image_1.jpg ne répond pas aux critères
# Image produit_248_image_0.jpg ne répond pas aux critères
# Image produit_251_image_0.jpg ne répond pas aux critères
# Image produit_251_image_1.jpg ne répond pas aux critères
# Image produit_253_image_0.jpg ne répond pas aux critères
# Image produit_270_image_3.jpg ne répond pas aux critères
# Image produit_272_image_0.jpg ne répond pas aux critères
# Image produit_277_image_0.jpg ne répond pas aux critères
# Image produit_279_image_4.jpg ne répond pas aux critères
# Image produit_280_image_3.jpg ne répond pas aux critères
# Image produit_283_image_2.jpg ne répond pas aux critères
# Image produit_283_image_3.jpg ne répond pas aux critères
# Image produit_286_image_2.jpg ne répond pas aux critères
# Image produit_289_image_0.jpg ne répond pas aux critères
# Image produit_289_image_1.jpg ne répond pas aux critères
# Image produit_295_image_3.jpg ne répond pas aux critères
# Image produit_313_image_0.jpg ne répond pas aux critères
# Image produit_313_image_3.jpg ne répond pas aux critères
# Image produit_316_image_4.jpg ne répond pas aux critères
# Image produit_318_image_4.jpg ne répond pas aux critères
# Image produit_319_image_4.jpg ne répond pas aux critères
# Image produit_321_image_1.jpg ne répond pas aux critères
# Image produit_321_image_3.jpg ne répond pas aux critères
# Image produit_323_image_0.jpg ne répond pas aux critères
# Image produit_323_image_2.jpg ne répond pas aux critères
# Image produit_323_image_3.jpg ne répond pas aux critères
# Image produit_323_image_5.jpg ne répond pas aux critères
# Image produit_323_image_6.jpg ne répond pas aux critères
# Image produit_324_image_3.jpg ne répond pas aux critères
# Image produit_324_image_5.jpg ne répond pas aux critères
# Image produit_330_image_2.jpg ne répond pas aux critères
# Image produit_331_image_3.jpg ne répond pas aux critères
# Image produit_333_image_0.jpg ne répond pas aux critères
# Image produit_333_image_1.jpg ne répond pas aux critères
# Image produit_333_image_2.jpg ne répond pas aux critères
# Image produit_333_image_3.jpg ne répond pas aux critères
# Image produit_334_image_2.jpg ne répond pas aux critères
# Image produit_355_image_0.jpg ne répond pas aux critères
# Image produit_355_image_1.jpg ne répond pas aux critères
# Image produit_373_image_1.jpg ne répond pas aux critères
# Image produit_380_image_0.jpg ne répond pas aux critères
# Image produit_380_image_1.jpg ne répond pas aux critères
# Image produit_394_image_2.jpg ne répond pas aux critères
# Image produit_401_image_2.jpg ne répond pas aux critères
# Image produit_405_image_0.jpg ne répond pas aux critères
# Image produit_405_image_3.jpg ne répond pas aux critères
# Image produit_411_image_0.jpg ne répond pas aux critères
# Image produit_411_image_1.jpg ne répond pas aux critères
# Image produit_411_image_4.jpg ne répond pas aux critères
# Image produit_412_image_5.jpg ne répond pas aux critères
# Image produit_412_image_6.jpg ne répond pas aux critères
# Image produit_417_image_1.jpg ne répond pas aux critères
# Image produit_418_image_2.jpg ne répond pas aux critères
# Image produit_423_image_0.jpg ne répond pas aux critères
# Image produit_423_image_1.jpg ne répond pas aux critères
# Image produit_427_image_5.jpg ne répond pas aux critères
# Image produit_432_image_0.jpg ne répond pas aux critères
# Image produit_432_image_1.jpg ne répond pas aux critères
# Image produit_437_image_3.jpg ne répond pas aux critères
# Image produit_437_image_4.jpg ne répond pas aux critères
# Image produit_444_image_0.jpg ne répond pas aux critères
# Image produit_447_image_2.jpg ne répond pas aux critères
# Image produit_463_image_3.jpg ne répond pas aux critères
# Image produit_467_image_0.jpg ne répond pas aux critères
# Image produit_472_image_1.jpg ne répond pas aux critères
# Image produit_475_image_1.jpg ne répond pas aux critères
# Image produit_476_image_0.jpg ne répond pas aux critères
# Image produit_476_image_1.jpg ne répond pas aux critères
# Image produit_476_image_2.jpg ne répond pas aux critères
# Image produit_478_image_6.jpg ne répond pas aux critères
# Image produit_479_image_4.jpg ne répond pas aux critères
# Image produit_484_image_5.jpg ne répond pas aux critères
# Image produit_484_image_9.jpg ne répond pas aux critères
# Image produit_484_image_10.jpg ne répond pas aux critères
# Image produit_485_image_0.jpg ne répond pas aux critères
# Image produit_485_image_1.jpg ne répond pas aux critères
# Image produit_485_image_3.jpg ne répond pas aux critères
# Image produit_485_image_4.jpg ne répond pas aux critères
# Image produit_485_image_5.jpg ne répond pas aux critères
# Image produit_494_image_3.jpg ne répond pas aux critères
# Image produit_494_image_4.jpg ne répond pas aux critères
# Image produit_502_image_1.jpg ne répond pas aux critères
# Image produit_514_image_2.jpg ne répond pas aux critères
# Image produit_522_image_2.jpg ne répond pas aux critères
# Image produit_524_image_3.jpg ne répond pas aux critères
# Image produit_524_image_5.jpg ne répond pas aux critères
# Image produit_548_image_0.jpg ne répond pas aux critères
# Image produit_555_image_5.jpg ne répond pas aux critères
# Image produit_555_image_7.jpg ne répond pas aux critères
# Image produit_562_image_4.jpg ne répond pas aux critères
# Image produit_563_image_2.jpg ne répond pas aux critères
# Image produit_564_image_0.jpg ne répond pas aux critères
# Image produit_564_image_1.jpg ne répond pas aux critères
# Image produit_564_image_2.jpg ne répond pas aux critères
# Image produit_564_image_4.jpg ne répond pas aux critères
# Image produit_575_image_6.jpg ne répond pas aux critères
# Image produit_577_image_1.jpg ne répond pas aux critères
# Image produit_599_image_0.jpg ne répond pas aux critères
# Image produit_599_image_1.jpg ne répond pas aux critères
# Image produit_599_image_2.jpg ne répond pas aux critères
# Image produit_599_image_3.jpg ne répond pas aux critères
# Image produit_600_image_2.jpg ne répond pas aux critères
# Image produit_600_image_3.jpg ne répond pas aux critères
# Image produit_603_image_4.jpg ne répond pas aux critères
# Image produit_608_image_5.jpg ne répond pas aux critères
# Image produit_608_image_6.jpg ne répond pas aux critères
# Image produit_609_image_0.jpg ne répond pas aux critères
# Image produit_609_image_1.jpg ne répond pas aux critères
# Image produit_621_image_0.jpg ne répond pas aux critères
# Image produit_621_image_1.jpg ne répond pas aux critères
# Image produit_621_image_2.jpg ne répond pas aux critères
# Image produit_621_image_3.jpg ne répond pas aux critères
# Image produit_621_image_4.jpg ne répond pas aux critères
# Image produit_621_image_5.jpg ne répond pas aux critères
# Image produit_636_image_0.jpg ne répond pas aux critères
# Image produit_636_image_1.jpg ne répond pas aux critères
# Image produit_636_image_2.jpg ne répond pas aux critères
# Image produit_636_image_3.jpg ne répond pas aux critères
# Image produit_637_image_2.jpg ne répond pas aux critères
# Image produit_647_image_1.jpg ne répond pas aux critères
# Image produit_668_image_5.jpg ne répond pas aux critères
# Image produit_668_image_17.jpg ne répond pas aux critères
# Image produit_671_image_1.jpg ne répond pas aux critères
# Image produit_678_image_0.jpg ne répond pas aux critères
# Image produit_684_image_0.jpg ne répond pas aux critères
# Image produit_684_image_1.jpg ne répond pas aux critères
# Image produit_684_image_3.jpg ne répond pas aux critères
# Image produit_687_image_0.jpg ne répond pas aux critères
# Image produit_688_image_0.jpg ne répond pas aux critères
# Image produit_688_image_1.jpg ne répond pas aux critères
# Image produit_688_image_2.jpg ne répond pas aux critères
# Image produit_692_image_5.jpg ne répond pas aux critères
# Image produit_694_image_1.jpg ne répond pas aux critères
# Image produit_694_image_2.jpg ne répond pas aux critères
# Image produit_695_image_0.jpg ne répond pas aux critères
# Image produit_695_image_1.jpg ne répond pas aux critères
# Image produit_726_image_2.jpg ne répond pas aux critères
# Image produit_739_image_6.jpg ne répond pas aux critères
# Image produit_748_image_3.jpg ne répond pas aux critères
# Image produit_758_image_3.jpg ne répond pas aux critères
# Image produit_758_image_4.jpg ne répond pas aux critères
# Image produit_770_image_3.jpg ne répond pas aux critères
# Image produit_773_image_0.jpg ne répond pas aux critères
# Image produit_773_image_1.jpg ne répond pas aux critères
# Image produit_775_image_0.jpg ne répond pas aux critères
# Image produit_782_image_0.jpg ne répond pas aux critères
# Image produit_784_image_0.jpg ne répond pas aux critères
# Image produit_795_image_0.jpg ne répond pas aux critères
# Image produit_801_image_0.jpg ne répond pas aux critères
# Image produit_801_image_1.jpg ne répond pas aux critères
# Image produit_804_image_0.jpg ne répond pas aux critères
# Image produit_804_image_1.jpg ne répond pas aux critères
# Image produit_816_image_2.jpg ne répond pas aux critères
# Image produit_826_image_0.jpg ne répond pas aux critères
# Image produit_826_image_1.jpg ne répond pas aux critères
# Image produit_838_image_4.jpg ne répond pas aux critères
# Image produit_845_image_1.jpg ne répond pas aux critères
# Image produit_859_image_0.jpg ne répond pas aux critères
# Image produit_866_image_5.jpg ne répond pas aux critères
# Image produit_868_image_0.jpg ne répond pas aux critères
# Image produit_868_image_1.jpg ne répond pas aux critères
# Image produit_868_image_2.jpg ne répond pas aux critères
# Image produit_868_image_3.jpg ne répond pas aux critères
# Image produit_869_image_0.jpg ne répond pas aux critères
# Image produit_869_image_1.jpg ne répond pas aux critères
# Image produit_869_image_2.jpg ne répond pas aux critères
# Image produit_873_image_2.jpg ne répond pas aux critères
# Image produit_873_image_3.jpg ne répond pas aux critères
# Image produit_878_image_0.jpg ne répond pas aux critères
# Image produit_878_image_2.jpg ne répond pas aux critères
# Image produit_880_image_0.jpg ne répond pas aux critères
# Image produit_880_image_1.jpg ne répond pas aux critères
# Image produit_897_image_0.jpg ne répond pas aux critères
# Image produit_917_image_0.jpg ne répond pas aux critères
# Image produit_928_image_7.jpg ne répond pas aux critères
# Image produit_928_image_9.jpg ne répond pas aux critères
# Image produit_930_image_2.jpg ne répond pas aux critères
# Image produit_943_image_2.jpg ne répond pas aux critères
# Image produit_951_image_0.jpg ne répond pas aux critères
# Image produit_956_image_4.jpg ne répond pas aux critères
# Image produit_957_image_2.jpg ne répond pas aux critères
# Image produit_958_image_3.jpg ne répond pas aux critères
# Image produit_959_image_0.jpg ne répond pas aux critères
# Image produit_960_image_0.jpg ne répond pas aux critères
# Image produit_960_image_2.jpg ne répond pas aux critères
# Image produit_960_image_3.jpg ne répond pas aux critères
# Image produit_960_image_4.jpg ne répond pas aux critères
# Image produit_960_image_6.jpg ne répond pas aux critères
# Image produit_962_image_3.jpg ne répond pas aux critères
# Image produit_963_image_0.jpg ne répond pas aux critères
# Image produit_970_image_2.jpg ne répond pas aux critères
# Image produit_972_image_3.jpg ne répond pas aux critères
# Image produit_974_image_5.jpg ne répond pas aux critères
# Image produit_981_image_0.jpg ne répond pas aux critères
# Image produit_984_image_4.jpg ne répond pas aux critères
# Image produit_984_image_5.jpg ne répond pas aux critères
# Image produit_991_image_1.jpg ne répond pas aux critères
# Image produit_997_image_2.jpg ne répond pas aux critères
# Image produit_1011_image_0.jpg ne répond pas aux critères
# Image produit_1014_image_1.jpg ne répond pas aux critères
# Image produit_1020_image_6.jpg ne répond pas aux critères
# Image produit_1025_image_2.jpg ne répond pas aux critères
# Image produit_1027_image_0.jpg ne répond pas aux critères
# Image produit_1035_image_0.jpg ne répond pas aux critères
# Image produit_1040_image_0.jpg ne répond pas aux critères
# Image produit_1040_image_1.jpg ne répond pas aux critères
# Image produit_1040_image_2.jpg ne répond pas aux critères
# Image produit_1040_image_3.jpg ne répond pas aux critères
# Image produit_1040_image_4.jpg ne répond pas aux critères
# Image produit_1040_image_5.jpg ne répond pas aux critères
# Image produit_1041_image_8.jpg ne répond pas aux critères
# Image produit_1042_image_0.jpg ne répond pas aux critères
# Image produit_1046_image_0.jpg ne répond pas aux critères
# Image produit_1050_image_8.jpg ne répond pas aux critères
# Image produit_1064_image_1.jpg ne répond pas aux critères
# Image produit_1067_image_0.jpg ne répond pas aux critères
# Image produit_1069_image_0.jpg ne répond pas aux critères
# Image produit_1069_image_1.jpg ne répond pas aux critères
# Image produit_1069_image_2.jpg ne répond pas aux critères
# Image produit_1102_image_0.jpg ne répond pas aux critères
# Image produit_1102_image_1.jpg ne répond pas aux critères
# Image produit_1102_image_2.jpg ne répond pas aux critères
# Image produit_1147_image_1.jpg ne répond pas aux critères
# Image produit_1147_image_3.jpg ne répond pas aux critères
# Image produit_1154_image_3.jpg ne répond pas aux critères
# Image produit_1156_image_0.jpg ne répond pas aux critères
# Image produit_1156_image_1.jpg ne répond pas aux critères
# Image produit_1156_image_2.jpg ne répond pas aux critères
# Image produit_1160_image_0.jpg ne répond pas aux critères
# Image produit_1160_image_1.jpg ne répond pas aux critères
# Image produit_1160_image_2.jpg ne répond pas aux critères
# Image produit_1160_image_3.jpg ne répond pas aux critères
# Image produit_1160_image_4.jpg ne répond pas aux critères
# Image produit_1160_image_5.jpg ne répond pas aux critères
# Image produit_1160_image_6.jpg ne répond pas aux critères
# Image produit_1160_image_7.jpg ne répond pas aux critères
# Image produit_1160_image_8.jpg ne répond pas aux critères
# Image produit_1160_image_9.jpg ne répond pas aux critères
# Image produit_1164_image_5.jpg ne répond pas aux critères
# Image produit_1164_image_6.jpg ne répond pas aux critères
# Image produit_1172_image_5.jpg ne répond pas aux critères
# Image produit_1191_image_0.jpg ne répond pas aux critères
# Image produit_1191_image_1.jpg ne répond pas aux critères
# Image produit_1191_image_2.jpg ne répond pas aux critères
# Image produit_1193_image_0.jpg ne répond pas aux critères
# Image produit_1193_image_1.jpg ne répond pas aux critères
# Image produit_1193_image_2.jpg ne répond pas aux critères
# Image produit_1197_image_0.jpg ne répond pas aux critères
# Image produit_1201_image_0.jpg ne répond pas aux critères
# Image produit_1201_image_1.jpg ne répond pas aux critères
# Image produit_1201_image_2.jpg ne répond pas aux critères
# Image produit_1201_image_3.jpg ne répond pas aux critères
# Image produit_1201_image_4.jpg ne répond pas aux critères
# Image produit_1203_image_0.jpg ne répond pas aux critères
# Image produit_1203_image_1.jpg ne répond pas aux critères
# Image produit_1209_image_2.jpg ne répond pas aux critères
# Image produit_1218_image_0.jpg ne répond pas aux critères
# Image produit_1218_image_1.jpg ne répond pas aux critères
# Image produit_1218_image_2.jpg ne répond pas aux critères
# Image produit_1218_image_3.jpg ne répond pas aux critères
# Image produit_1218_image_4.jpg ne répond pas aux critères
# Image produit_1219_image_6.jpg ne répond pas aux critères
# Image produit_1224_image_1.jpg ne répond pas aux critères
# Image produit_1236_image_1.jpg ne répond pas aux critères
# Image produit_1268_image_4.jpg ne répond pas aux critères
# Image produit_1271_image_0.jpg ne répond pas aux critères
# Image produit_1271_image_1.jpg ne répond pas aux critères
# Image produit_1286_image_0.jpg ne répond pas aux critères
# Image produit_1304_image_0.jpg ne répond pas aux critères
# Image produit_1304_image_2.jpg ne répond pas aux critères
# Image produit_1304_image_4.jpg ne répond pas aux critères
# Image produit_1304_image_5.jpg ne répond pas aux critères
# Image produit_1304_image_6.jpg ne répond pas aux critères
# Image produit_1309_image_4.jpg ne répond pas aux critères
# Image produit_1318_image_1.jpg ne répond pas aux critères
# Image produit_1331_image_0.jpg ne répond pas aux critères
# Image produit_1332_image_3.jpg ne répond pas aux critères
# Image produit_1336_image_2.jpg ne répond pas aux critères
# Image produit_1350_image_1.jpg ne répond pas aux critères
# Image produit_1352_image_0.jpg ne répond pas aux critères
# Image produit_1352_image_1.jpg ne répond pas aux critères
# Image produit_1352_image_3.jpg ne répond pas aux critères
# Image produit_1352_image_5.jpg ne répond pas aux critères
# Image produit_1352_image_6.jpg ne répond pas aux critères
# Image produit_1362_image_0.jpg ne répond pas aux critères
# Image produit_1362_image_2.jpg ne répond pas aux critères
# Image produit_1362_image_3.jpg ne répond pas aux critères
# Image produit_1363_image_1.jpg ne répond pas aux critères
# Image produit_1363_image_3.jpg ne répond pas aux critères
# Image produit_1366_image_0.jpg ne répond pas aux critères
# Image produit_1366_image_2.jpg ne répond pas aux critères
# Image produit_1366_image_3.jpg ne répond pas aux critères
# Image produit_1366_image_5.jpg ne répond pas aux critères
# Image produit_1366_image_7.jpg ne répond pas aux critères
# Image produit_1366_image_8.jpg ne répond pas aux critères
# Image produit_1366_image_9.jpg ne répond pas aux critères
# Image produit_1366_image_10.jpg ne répond pas aux critères
# Image produit_1366_image_12.jpg ne répond pas aux critères
# Image produit_1376_image_3.jpg ne répond pas aux critères
# Image produit_1377_image_0.jpg ne répond pas aux critères
# Image produit_1377_image_1.jpg ne répond pas aux critères
# Image produit_1377_image_3.jpg ne répond pas aux critères
# Image produit_1407_image_1.jpg ne répond pas aux critères
# Image produit_1414_image_1.jpg ne répond pas aux critères
# Image produit_1427_image_1.jpg ne répond pas aux critères
# Image produit_1448_image_0.jpg ne répond pas aux critères
# Image produit_1452_image_1.jpg ne répond pas aux critères
# Image produit_1460_image_4.jpg ne répond pas aux critères
# Image produit_1472_image_0.jpg ne répond pas aux critères
# Image produit_1472_image_1.jpg ne répond pas aux critères
# Image produit_1472_image_2.jpg ne répond pas aux critères
# Image produit_1476_image_2.jpg ne répond pas aux critères
# Image produit_1480_image_0.jpg ne répond pas aux critères
# Image produit_1484_image_0.jpg ne répond pas aux critères
# Image produit_1491_image_0.jpg ne répond pas aux critères
# Image produit_1491_image_1.jpg ne répond pas aux critères
# Image produit_1491_image_2.jpg ne répond pas aux critères
# Image produit_1492_image_0.jpg ne répond pas aux critères
# Image produit_1492_image_1.jpg ne répond pas aux critères
# Image produit_1500_image_2.jpg ne répond pas aux critères
# Image produit_1501_image_2.jpg ne répond pas aux critères
# Image produit_1502_image_0.jpg ne répond pas aux critères
# Image produit_1512_image_5.jpg ne répond pas aux critères
# Image produit_1512_image_6.jpg ne répond pas aux critères
# Image produit_1524_image_0.jpg ne répond pas aux critères
# Image produit_1530_image_0.jpg ne répond pas aux critères
# Image produit_1540_image_7.jpg ne répond pas aux critères
# Image produit_1540_image_8.jpg ne répond pas aux critères
# Image produit_1540_image_9.jpg ne répond pas aux critères
# Image produit_1543_image_0.jpg ne répond pas aux critères
# Image produit_1544_image_4.jpg ne répond pas aux critères
# Image produit_1546_image_0.jpg ne répond pas aux critères
# Image produit_1546_image_1.jpg ne répond pas aux critères
# Image produit_1547_image_0.jpg ne répond pas aux critères
# Image produit_1547_image_1.jpg ne répond pas aux critères
# Image produit_1547_image_2.jpg ne répond pas aux critères
# Image produit_1549_image_7.jpg ne répond pas aux critères
# Image produit_1549_image_8.jpg ne répond pas aux critères
# Image produit_1549_image_9.jpg ne répond pas aux critères
# Image produit_1549_image_10.jpg ne répond pas aux critères
# Image produit_1549_image_11.jpg ne répond pas aux critères
# Image produit_1549_image_12.jpg ne répond pas aux critères
# Image produit_1549_image_13.jpg ne répond pas aux critères
# Image produit_1549_image_14.jpg ne répond pas aux critères
# Image produit_1554_image_4.jpg ne répond pas aux critères
# Image produit_1559_image_0.jpg ne répond pas aux critères
# Image produit_1559_image_1.jpg ne répond pas aux critères
# Image produit_1563_image_0.jpg ne répond pas aux critères
# Image produit_1563_image_1.jpg ne répond pas aux critères
# Image produit_1563_image_2.jpg ne répond pas aux critères
# Image produit_1563_image_3.jpg ne répond pas aux critères
# Image produit_1563_image_4.jpg ne répond pas aux critères
# Image produit_1563_image_5.jpg ne répond pas aux critères
# Image produit_1563_image_6.jpg ne répond pas aux critères
# Image produit_1570_image_0.jpg ne répond pas aux critères
# Image produit_1572_image_4.jpg ne répond pas aux critères
# Image produit_1579_image_0.jpg ne répond pas aux critères
# Image produit_1582_image_0.jpg ne répond pas aux critères
# Image produit_1582_image_1.jpg ne répond pas aux critères
# Image produit_1584_image_1.jpg ne répond pas aux critères
# Image produit_1584_image_5.jpg ne répond pas aux critères
# Image produit_1584_image_6.jpg ne répond pas aux critères
# Image produit_1584_image_7.jpg ne répond pas aux critères
# Image produit_1587_image_0.jpg ne répond pas aux critères
# Image produit_1587_image_1.jpg ne répond pas aux critères
# Image produit_1587_image_2.jpg ne répond pas aux critères
# Image produit_1600_image_2.jpg ne répond pas aux critères
# Image produit_1603_image_5.jpg ne répond pas aux critères
# Image produit_1606_image_4.jpg ne répond pas aux critères
# Image produit_1608_image_2.jpg ne répond pas aux critères
# Image produit_1608_image_3.jpg ne répond pas aux critères
# Image produit_1610_image_6.jpg ne répond pas aux critères
# Image produit_1614_image_6.jpg ne répond pas aux critères
# Image produit_1617_image_0.jpg ne répond pas aux critères
# Image produit_1617_image_7.jpg ne répond pas aux critères
# Image produit_1618_image_0.jpg ne répond pas aux critères
# Image produit_1625_image_0.jpg ne répond pas aux critères
# Image produit_1630_image_2.jpg ne répond pas aux critères
# Image produit_1630_image_3.jpg ne répond pas aux critères
# Image produit_1630_image_4.jpg ne répond pas aux critères
# Image produit_1631_image_2.jpg ne répond pas aux critères
# Image produit_1645_image_1.jpg ne répond pas aux critères
# Image produit_1645_image_3.jpg ne répond pas aux critères
# Image produit_1649_image_5.jpg ne répond pas aux critères
# Image produit_1649_image_6.jpg ne répond pas aux critères
# Image produit_1650_image_1.jpg ne répond pas aux critères
# Image produit_1650_image_2.jpg ne répond pas aux critères
# Image produit_1654_image_3.jpg ne répond pas aux critères
# Image produit_1665_image_0.jpg ne répond pas aux critères
# Image produit_1671_image_1.jpg ne répond pas aux critères
# Image produit_1673_image_0.jpg ne répond pas aux critères
# Image produit_1673_image_1.jpg ne répond pas aux critères
# Image produit_1674_image_0.jpg ne répond pas aux critères
# Image produit_1676_image_0.jpg ne répond pas aux critères
# Image produit_1682_image_0.jpg ne répond pas aux critères
# Image produit_1682_image_4.jpg ne répond pas aux critères
# Image produit_1683_image_0.jpg ne répond pas aux critères
# Image produit_1683_image_1.jpg ne répond pas aux critères
# Image produit_1685_image_0.jpg ne répond pas aux critères
# Image produit_1685_image_1.jpg ne répond pas aux critères
# Image produit_1685_image_2.jpg ne répond pas aux critères
# Image produit_1691_image_0.jpg ne répond pas aux critères
# Image produit_1691_image_1.jpg ne répond pas aux critères
# Image produit_1691_image_2.jpg ne répond pas aux critères
# Image produit_1691_image_3.jpg ne répond pas aux critères
# Image produit_1691_image_4.jpg ne répond pas aux critères
# Image produit_1691_image_5.jpg ne répond pas aux critères
# Image produit_1693_image_0.jpg ne répond pas aux critères
# Image produit_1697_image_1.jpg ne répond pas aux critères
# Image produit_1697_image_2.jpg ne répond pas aux critères
# Image produit_1697_image_3.jpg ne répond pas aux critères
# Image produit_1698_image_1.jpg ne répond pas aux critères
# Image produit_1698_image_2.jpg ne répond pas aux critères
# Image produit_1698_image_4.jpg ne répond pas aux critères
# Image produit_1698_image_5.jpg ne répond pas aux critères
# Image produit_1698_image_6.jpg ne répond pas aux critères
# Image produit_1700_image_4.jpg ne répond pas aux critères
# Image produit_1702_image_1.jpg ne répond pas aux critères
# Image produit_1705_image_0.jpg ne répond pas aux critères
# Image produit_1705_image_1.jpg ne répond pas aux critères
# Image produit_1705_image_2.jpg ne répond pas aux critères
# Image produit_1708_image_4.jpg ne répond pas aux critères
#                     Image_Path Condition
# 0        produit_0_image_0.jpg         3
# 3        produit_3_image_1.jpg         3
# 4        produit_5_image_0.jpg         2
# 7        produit_6_image_1.jpg         4
# 9        produit_7_image_0.jpg         2
# ...                        ...       ...
# 4782  produit_1717_image_0.jpg         3
# 4783  produit_1717_image_1.jpg         3
# 4787  produit_1718_image_0.jpg         3
# 4788  produit_1718_image_1.jpg         3
# 4790  produit_1718_image_3.jpg         3
#
# [2143 rows x 2 columns]

# %% [markdown]
# # Non utilisé pour l'instant

# %% [markdown]
# ## Évaluation de la pertinence

# %%
"""
# Fonction pour générer le prompt dynamique
def dynamic_prompt(condition):
    condition_mapping = {
        0: 'For parts',
        1: 'Satisfactory condition',
        2: 'Good condition',
        3: 'Very good condition',
        4: 'Brand new',
    }
    state = condition_mapping.get(condition, 'Unknown condition')
    
    prompt = f'''
    The claimed condition for this smartphone is: {state}

    Please analyze the image carefully to determine if the claimed condition approximately matches the actual visual condition.

    Based on your analysis, respond accordingly.
    '''
    return prompt


# Définition du system_prompt
system_prompt = '''
You are an expert in smartphone evaluation. Your task is to compare the claimed condition of a smartphone with its actual visual condition based on the provided image.

Possible conditions are:
- 'For parts'
- 'Satisfactory condition'
- 'Good condition'
- 'Very good condition'
- 'Brand new'

Instructions:
- If the claimed condition approximately matches the visual condition of the smartphone in the image, respond with "Okay".
- If it does not match, provide the condition level that is one level higher or lower than the claimed condition, as appropriate.
- Respond only with "Okay" or the adjusted condition level. Do not include any explanations or additional information.
'''

"""
# Out:
# '\n# Fonction pour générer le prompt dynamique\ndef dynamic_prompt(condition):\n    condition_mapping = {\n        0: \'For parts\',\n        1: \'Satisfactory condition\',\n        2: \'Good condition\',\n        3: \'Very good condition\',\n        4: \'Brand new\',\n    }\n    state = condition_mapping.get(condition, \'Unknown condition\')\n    \n    prompt = f\'\'\'\n    The claimed condition for this smartphone is: {state}\n\n    Please analyze the image carefully to determine if the claimed condition approximately matches the actual visual condition.\n\n    Based on your analysis, respond accordingly.\n    \'\'\'\n    return prompt\n\n\n# Définition du system_prompt\nsystem_prompt = \'\'\'\nYou are an expert in smartphone evaluation. Your task is to compare the claimed condition of a smartphone with its actual visual condition based on the provided image.\n\nPossible conditions are:\n- \'For parts\'\n- \'Satisfactory condition\'\n- \'Good condition\'\n- \'Very good condition\'\n- \'Brand new\'\n\nInstructions:\n- If the claimed condition approximately matches the visual condition of the smartphone in the image, respond with "Okay".\n- If it does not match, provide the condition level that is one level higher or lower than the claimed condition, as appropriate.\n- Respond only with "Okay" or the adjusted condition level. Do not include any explanations or additional information.\n\'\'\'\n\n'

# %%
"""

# Fonction pour mapper l'état à un numéro
def state_number(condition, state):
    state_mapping = {
        'For parts': 0,
        'Satisfactory condition': 1,
        'Good condition': 2,
        'Very good condition': 3,
        'Brand new': 4,
        'Okay': condition,
    }
    return state_mapping.get(state, None)

# Fonction pour traiter le DataFrame
def process_dataframe(model_name, system_prompt, generation_config, dataframe):
    df = dataframe.copy()
    df['Gemini_Response'] = ''

    for idx, row in df.iterrows():
        image_name = row['Image_Path']
        image_path = f"Data/{iteration}/images_without_background/{image_name}"
        
        condition = row['Condition']
        
        # Obtenir la réponse
        answer = analyze_image(
            image_path=image_path, 
            system_prompt=system_prompt, 
            prompt=dynamic_prompt(condition),
            model_name=model_name, 
            generation_config=generation_config
        )

        number = state_number(condition, answer)
        
        # Stocker la réponse
        df.at[idx, 'Gemini_Response'] = number
    return df
    
    
    """
# Out:
# '\n\n# Fonction pour mapper l\'état à un numéro\ndef state_number(condition, state):\n    state_mapping = {\n        \'For parts\': 0,\n        \'Satisfactory condition\': 1,\n        \'Good condition\': 2,\n        \'Very good condition\': 3,\n        \'Brand new\': 4,\n        \'Okay\': condition,\n    }\n    return state_mapping.get(state, None)\n\n# Fonction pour traiter le DataFrame\ndef process_dataframe(model_name, system_prompt, generation_config, dataframe):\n    df = dataframe.copy()\n    df[\'Gemini_Response\'] = \'\'\n\n    for idx, row in df.iterrows():\n        image_name = row[\'Image_Path\']\n        image_path = f"Data/{iteration}/images_without_background/{image_name}"\n        \n        condition = row[\'Condition\']\n        \n        # Obtenir la réponse\n        answer = analyze_image(\n            image_path=image_path, \n            system_prompt=system_prompt, \n            prompt=dynamic_prompt(condition),\n            model_name=model_name, \n            generation_config=generation_config\n        )\n\n        number = state_number(condition, answer)\n        \n        # Stocker la réponse\n        df.at[idx, \'Gemini_Response\'] = number\n    return df\n    \n    \n    '

# %%
"""

# Nom du modèle et configuration de génération
model_name = "gemini-1.5-flash"
generation_config = {
    "temperature": 0.2,
    "top_p": 0.9,
    "top_k": 40,
    "max_output_tokens": 150,
    "response_mime_type": "text/plain",
}

# Traitement des DataFrames df_front et df_back
df_front_final = process_dataframe(model_name, system_prompt, generation_config, df_front)
df_back_final = process_dataframe(model_name, system_prompt, generation_config, df_back)

# Sauvegarder les DataFrames traités
df_front_final.to_csv(f'Data/{iteration}/df_front_{iteration}.csv', index=False)
df_back_final.to_csv(f'Data/{iteration}/df_back_{iteration}.csv', index=False)

"""
# Out:
# '\n\n# Nom du modèle et configuration de génération\nmodel_name = "gemini-1.5-flash"\ngeneration_config = {\n    "temperature": 0.2,\n    "top_p": 0.9,\n    "top_k": 40,\n    "max_output_tokens": 150,\n    "response_mime_type": "text/plain",\n}\n\n# Traitement des DataFrames df_front et df_back\ndf_front_final = process_dataframe(model_name, system_prompt, generation_config, df_front)\ndf_back_final = process_dataframe(model_name, system_prompt, generation_config, df_back)\n\n# Sauvegarder les DataFrames traités\ndf_front_final.to_csv(f\'Data/{iteration}/df_front_{iteration}.csv\', index=False)\ndf_back_final.to_csv(f\'Data/{iteration}/df_back_{iteration}.csv\', index=False)\n\n'
